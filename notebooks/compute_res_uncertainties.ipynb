# %%
import sys
import numpy as np
import pandas as pd

import time
import json

from matplotlib import pyplot as plt
from scipy.optimize import minimize
from scipy.special import erf
from statsmodels.stats.proportion import proportion_confint

sys.path.append('/home/rusack/joshib/HGCALDRNElectron') # change this path to your own directory
from utils.pltutils import plt
from utils.fit_utils import *

# %%
import pickle

# %%
scaled_data_gaus_fits = 'plots/pkl/rechit_energy_sum_data_scaled.pkl'
mv_gaus_fits = 'plots/pkl/rechit_energy_sum_mc.pkl'

# %%
# set custom functions
plt.rcParams['axes.linewidth'] = 1.4
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['ytick.minor.size'] = 2.5
plt.rcParams['xtick.minor.size'] = 4.0
plt.rcParams['ytick.minor.visible'] = True
plt.rcParams['ytick.labelsize'] = 'large'
plt.rcParams['xtick.labelsize'] = 'large'

# %%
def model(x, par):
    return par[0], gaussian(x, par[0], par[1], par[2])

# %%
with open(scaled_data_gaus_fits,'rb') as f0:
    data_hist2_array = pickle.load(f0)
